# %%
import csv
originalData = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/ORIGINAL_teamdata.csv"
changedData = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/TRAINABLE_teamdata.csv"
data2002 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2002_teamdata.csv"
data2003 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2003_teamdata.csv"
data2004 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2004_teamdata.csv"
data2005 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2005_teamdata.csv"
data2006 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2006_teamdata.csv"
data2007 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2007_teamdata.csv"
data2008 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2008_teamdata.csv"
data2009 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2009_teamdata.csv"
data2010 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2010_teamdata.csv"
data2011 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2011_teamdata.csv"
data2012 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2012_teamdata.csv"
data2013 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2013_teamdata.csv"
data2014 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2014_teamdata.csv"
data2015 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2015_teamdata.csv"
data2016 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2016_teamdata.csv"
data2017 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2017_teamdata.csv"
data2018 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2018_teamdata.csv"
data2019 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2019_teamdata.csv"
data2020 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2020_teamdata.csv"
data2021 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2021_teamdata.csv"
data2022 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2022_teamdata.csv"
data2023 = "/Users/reubencovey/Desktop/CS 4641 - ML/Project/2023_teamdata.csv"

# %%
def readFile(path):
    results = []
    with open(path, mode='r') as file:
        reader = csv.reader(file)
        for row in reader:
            results.append(row)
    return results

def writeFile(path, data):
    with open(path, 'w', newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)
        
def appendFile(path, data):
    with open(path, 'a', newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)

def convertTOP(top):
    split = top.split(":")
    minutes = int(split[0])
    seconds = int(split[1])
    return (minutes * 60) + seconds

def initTeams():
    Niners = Team("49ers")
    Giants = Team("Giants")
    Colts = Team("Colts")
    Jaguars = Team("Jaguars")
    Cardinals = Team("Cardinals")
    Commanders = Team("Commanders")
    Lions = Team("Lions")
    Dolphins = Team("Dolphins")
    Eagles = Team("Eagles")
    Titans = Team("Titans")
    Ravens = Team("Ravens")
    Panthers = Team("Panthers")
    Chiefs = Team("Chiefs")
    Browns = Team("Browns")
    Chargers = Team("Chargers")
    Bengals = Team("Bengals")
    Vikings = Team("Vikings")
    Bears = Team("Bears")
    Jets = Team("Jets")
    Bills = Team("Bills")
    Falcons = Team("Falcons")
    Packers = Team("Packers")
    Rams = Team("Rams")
    Broncos = Team("Broncos")
    Seahawks = Team("Seahawks")
    Raiders = Team("Raiders")
    Saints = Team("Saints")
    Buccaneers = Team("Buccaneers")
    Cowboys = Team("Cowboys")
    Texans = Team("Texans")
    Steelers = Team("Steelers")
    Patriots = Team("Patriots")
    teams = {
        "49ers": Niners,
        "Giants": Giants,
        "Colts": Colts,
        "Jaguars": Jaguars,
        "Cardinals": Cardinals,
        "Commanders": Commanders,
        "Lions": Lions,
        "Dolphins": Dolphins,
        "Eagles": Eagles,
        "Titans": Titans,
        "Ravens": Ravens,
        "Panthers": Panthers,
        "Chiefs": Chiefs,
        "Browns": Browns,
        "Chargers": Chargers,
        "Bengals": Bengals,
        "Vikings": Vikings,
        "Bears": Bears,
        "Jets": Jets,
        "Bills": Bills,
        "Falcons": Falcons,
        "Packers": Packers,
        "Rams": Rams,
        "Broncos": Broncos,
        "Seahawks": Seahawks,
        "Raiders": Raiders,
        "Saints": Saints,
        "Buccaneers": Buccaneers,
        "Cowboys": Cowboys,
        "Texans": Texans,
        "Steelers": Steelers,
        "Patriots": Patriots
    }
    return teams

def updateStats(teams, newdata):
    awayTeam = newdata[5]
    homeTeam = newdata[6]
    awayObject = teams[awayTeam]
    homeObject = teams[homeTeam]
    
    awayObject.numWeeks += 1
    homeObject.numWeeks += 1
    
    awayObject.points += int(newdata[7])
    homeObject.pointsAllowed += int(newdata[7])
    homeObject.points += int(newdata[8])
    awayObject.pointsAllowed += int(newdata[8])
    
    awayObject.firstdowns += int(newdata[9])
    homeObject.firstdownsAllowed += int(newdata[9])
    homeObject.firstdowns += int(newdata[10])
    awayObject.firstdownsAllowed += int(newdata[10])
    
    awayObject.firstdownspassing += int(newdata[11])
    homeObject.firstdownspassingAllowed += int(newdata[11])
    homeObject.firstdownspassing += int(newdata[12])
    awayObject.firstdownspassingAllowed += int(newdata[12])
    
    awayObject.firstdownsrushing += int(newdata[13])
    homeObject.firstdownsrushingAllowed += int(newdata[13])
    homeObject.firstdownsrushing += int(newdata[14])
    awayObject.firstdownsrushingAllowed += int(newdata[14])
    
    awayObject.firstdownspenalty += int(newdata[15])
    homeObject.firstdownspenaltyAllowed += int(newdata[15])
    homeObject.firstdownspenalty += int(newdata[16])
    awayObject.firstdownspenaltyAllowed += int(newdata[16])
    
    awayObject.thirddowncompletions += int(newdata[17])
    homeObject.thirddowncompletionsAllowed += int(newdata[17])
    awayObject.thirddownattempts += int(newdata[18])
    homeObject.thirddownattemptsAllowed += int(newdata[18])
    
    homeObject.thirddowncompletions += int(newdata[19])
    awayObject.thirddowncompletionsAllowed += int(newdata[19])
    homeObject.thirddownattempts += int(newdata[20])
    awayObject.thirddownattemptsAllowed += int(newdata[20])
    
    awayObject.fourthdowncompletions += int(newdata[21])
    homeObject.fourthdowncompletionsAllowed += int(newdata[21])
    awayObject.fourthdownattempts += int(newdata[22])
    homeObject.fourthdownattemptsAllowed += int(newdata[22])
    
    homeObject.fourthdowncompletions += int(newdata[23])
    awayObject.fourthdowncompletionsAllowed += int(newdata[23])
    homeObject.fourthdownattempts += int(newdata[24])
    awayObject.fourthdownattemptsAllowed += int(newdata[24])
    
    awayObject.plays += int(newdata[25])
    homeObject.playsAllowed += int(newdata[25])
    homeObject.plays += int(newdata[26])
    awayObject.playsAllowed += int(newdata[26])
    
    awayObject.drives += int(newdata[27])
    homeObject.drivesAllowed += int(newdata[27])
    homeObject.drives += int(newdata[28])
    awayObject.drivesAllowed += int(newdata[28])
    
    awayObject.yards += int(newdata[29])
    homeObject.yardsAllowed += int(newdata[29])
    homeObject.yards += int(newdata[30])
    awayObject.yardsAllowed += int(newdata[30])
    
    awayObject.passcompletions += int(newdata[31])
    awayObject.passattempts += int(newdata[32])
    awayObject.passyards += int(newdata[33])
    homeObject.passcompletionsAllowed += int(newdata[31])
    homeObject.passattemptsAllowed += int(newdata[32])
    homeObject.passyardsAllowed += int(newdata[33])
    
    homeObject.passcompletions += int(newdata[34])
    homeObject.passattempts += int(newdata[35])
    homeObject.passyards += int(newdata[36])
    awayObject.passcompletionsAllowed += int(newdata[34])
    awayObject.passattemptsAllowed += int(newdata[35])
    awayObject.passyardsAllowed += int(newdata[36])
    
    awayObject.numsacks += int(newdata[37])
    awayObject.sackyards += int(newdata[38])
    homeObject.numsacksAllowed += int(newdata[37])
    homeObject.sackyardsAllowed += int(newdata[38])
    
    homeObject.numsacks += int(newdata[39])
    homeObject.sackyards += int(newdata[40])
    awayObject.numsacksAllowed += int(newdata[39])
    awayObject.sackyardsAllowed += int(newdata[40])
    
    awayObject.rushattempts += int(newdata[41])
    awayObject.rushyards += int(newdata[42])
    homeObject.rushattemptsAllowed += int(newdata[41])
    homeObject.rushyardsAllowed += int(newdata[42])
    
    homeObject.rushattempts += int(newdata[43])
    homeObject.rushyards += int(newdata[44])
    awayObject.rushattemptsAllowed += int(newdata[43])
    awayObject.rushyardsAllowed += int(newdata[44])
    
    awayObject.numpenalties += int(newdata[45])
    awayObject.penaltyyards += int(newdata[46])
    homeObject.numpenalties += int(newdata[47])
    homeObject.penaltyyards += int(newdata[48])
    
    awayObject.fumbles += int(newdata[53])
    homeObject.fumblesrecovered += int(newdata[53])
    homeObject.fumbles += int(newdata[54])
    awayObject.fumblesrecovered += int(newdata[54])
    
    awayObject.interceptions += int(newdata[55])
    homeObject.interceptionsrecovered += int(newdata[55])
    homeObject.interceptions += int(newdata[56])
    awayObject.interceptionsrecovered += int(newdata[56])
    
    awayObject.timeofpossession += convertTOP(newdata[59])
    homeObject.timeofpossession += convertTOP(newdata[60])
    
def createDatapoint(teams, newdata):
    awayTeam = newdata[5]
    homeTeam = newdata[6]
    awayObject = teams[awayTeam]
    homeObject = teams[homeTeam]
    awayWeeks = awayObject.numWeeks
    homeWeeks = homeObject.numWeeks
    datapoint = None
    if awayWeeks == 0 or homeWeeks == 0:
        return datapoint
    
    season = newdata[0]
    week = newdata[1]
    time_et = newdata[3]
    neutral = newdata[4]
    score_away = newdata[7]
    score_home = newdata[8]
    ppg_away = round(awayObject.points / awayWeeks, 2)
    papg_away = round(awayObject.pointsAllowed / awayWeeks, 2)
    ppg_home = round(homeObject.points / homeWeeks, 2)
    papg_home = round(homeObject.pointsAllowed / homeWeeks, 2)
    first_downs_away = round(awayObject.firstdowns / awayWeeks, 2)
    first_downs_away_allowed = round(awayObject.firstdownsAllowed / awayWeeks, 2)
    first_downs_home = round(homeObject.firstdowns / homeWeeks, 2)
    first_downs_home_allowed = round(homeObject.firstdownsAllowed / homeWeeks, 2)
    first_downs_from_passing_away = round(awayObject.firstdownspassing / awayWeeks, 2)
    first_downs_from_passing_away_allowed = round(awayObject.firstdownspassingAllowed / awayWeeks, 2)
    first_downs_from_passing_home = round(homeObject.firstdownspassing / homeWeeks, 2)
    first_downs_from_passing_home_allowed = round(homeObject.firstdownspassingAllowed / homeWeeks, 2)
    
    first_downs_from_rushing_away = round(awayObject.firstdownsrushing / awayWeeks, 2)
    first_downs_from_rushing_away_allowed = round(awayObject.firstdownsrushingAllowed / awayWeeks, 2)
    first_downs_from_rushing_home = round(homeObject.firstdownsrushing / homeWeeks, 2)
    first_downs_from_rushing_home_allowed = round(homeObject.firstdownsrushingAllowed / homeWeeks, 2)
    first_downs_from_penalty_away = round(awayObject.firstdownspenalty / awayWeeks, 2)
    first_downs_from_penalty_away_allowed = round(awayObject.firstdownspenaltyAllowed / awayWeeks, 2)
    first_downs_from_penalty_home = round(homeObject.firstdownspenalty / homeWeeks, 2)
    first_downs_from_penalty_home_allowed = round(homeObject.firstdownspenaltyAllowed / homeWeeks, 2)
    third_down_comp_away = round(awayObject.thirddowncompletions / awayWeeks, 2)
    third_down_comp_away_allowed = round(awayObject.thirddowncompletionsAllowed / awayWeeks, 2)
    third_down_att_away = round(awayObject.thirddownattempts / awayWeeks, 2)
    third_down_att_away_allowed = round(awayObject.thirddownattemptsAllowed / awayWeeks, 2)
    third_down_comp_home = round(homeObject.thirddowncompletions / homeWeeks, 2)
    third_down_comp_home_allowed = round(homeObject.thirddowncompletionsAllowed  / homeWeeks, 2)
    third_down_att_home = round(homeObject.thirddownattempts / homeWeeks, 2)
    third_down_att_home_allowed = round(homeObject.thirddownattemptsAllowed / homeWeeks, 2)
    fourth_down_comp_away = round(awayObject.fourthdowncompletions / awayWeeks, 2)
    fourth_down_comp_away_allowed = round(awayObject.fourthdowncompletionsAllowed / awayWeeks, 2)
    fourth_down_att_away = round(awayObject.fourthdownattempts / awayWeeks, 2)
    fourth_down_att_away_allowed = round(awayObject.fourthdownattemptsAllowed / awayWeeks, 2)
    fourth_down_comp_home = round(homeObject.fourthdowncompletions / homeWeeks, 2)
    fourth_down_comp_home_allowed = round(homeObject.fourthdowncompletionsAllowed  / homeWeeks, 2)
    fourth_down_att_home = round(homeObject.fourthdownattempts / homeWeeks, 2)
    fourth_down_att_home_allowed = round(homeObject.fourthdownattemptsAllowed / homeWeeks, 2)
    plays_away = round(awayObject.plays / awayWeeks, 2)
    plays_away_allowed = round(awayObject.playsAllowed / awayWeeks, 2)
    plays_home = round(homeObject.plays / homeWeeks, 2)
    plays_home_allowed = round(homeObject.playsAllowed / homeWeeks, 2)
    drives_away = round(awayObject.drives / awayWeeks, 2)
    drives_away_allowed = round(awayObject.drivesAllowed / awayWeeks, 2)
    drives_home = round(homeObject.drives / homeWeeks, 2)
    drives_home_allowed = round(homeObject.drivesAllowed / homeWeeks, 2)
    yards_away = round(awayObject.yards / awayWeeks, 2)
    yards_away_allowed = round(awayObject.yardsAllowed / awayWeeks, 2)
    yards_home = round(homeObject.yards / homeWeeks, 2)
    yards_home_allowed = round(homeObject.yardsAllowed / homeWeeks, 2)
    
    pass_comp_away = round(awayObject.passcompletions / awayWeeks, 2)
    pass_comp_away_allowed = round(awayObject.passcompletionsAllowed / awayWeeks, 2)
    pass_att_away = round(awayObject.passattempts / awayWeeks, 2)
    pass_att_away_allowed = round(awayObject.passattemptsAllowed / awayWeeks, 2)
    pass_yards_away = round(awayObject.passyards / awayWeeks, 2)
    pass_yards_away_allowed = round(awayObject.passyardsAllowed / awayWeeks, 2)
    pass_comp_home = round(homeObject.passcompletions / homeWeeks, 2)
    pass_comp_home_allowed = round(homeObject.passcompletionsAllowed / homeWeeks, 2)
    pass_att_home = round(homeObject.passattempts / homeWeeks, 2)
    pass_att_home_allowed = round(homeObject.passattemptsAllowed / homeWeeks, 2)
    pass_yards_home = round(homeObject.passyards / homeWeeks, 2)
    pass_yards_home_allowed = round(homeObject.passyardsAllowed / homeWeeks, 2)
    sacks_num_away = round(awayObject.numsacks / awayWeeks, 2)
    sacks_num_away_allowed = round(awayObject.numsacksAllowed / awayWeeks, 2)
    sacks_yards_away = round(awayObject.sackyards / awayWeeks, 2)
    sacks_yards_away_allowed = round(awayObject.sackyardsAllowed / awayWeeks, 2)
    sacks_num_home = round(homeObject.numsacks / homeWeeks, 2)
    sacks_num_home_allowed = round(homeObject.numsacksAllowed  / homeWeeks, 2)
    sacks_yards_home = round(homeObject.sackyards / homeWeeks, 2)
    sacks_yards_home_allowed = round(homeObject.sackyardsAllowed / homeWeeks, 2)
    rush_att_away = round(awayObject.rushattempts / awayWeeks, 2)
    rush_att_away_allowed = round(awayObject.rushattemptsAllowed / awayWeeks, 2)
    rush_yards_away = round(awayObject.rushyards / awayWeeks, 2)
    rush_yards_away_allowed = round(awayObject.rushyardsAllowed / awayWeeks, 2)
    rush_att_home = round(homeObject.rushattempts / homeWeeks, 2)
    rush_att_home_allowed = round(homeObject.rushattemptsAllowed / homeWeeks, 2)
    rush_yards_home = round(homeObject.rushyards / homeWeeks, 2)
    rush_yards_home_allowed = round(homeObject.rushyardsAllowed / homeWeeks, 2)
    pen_num_away = round(awayObject.numpenalties / awayWeeks, 2)
    pen_yards_away = round(awayObject.penaltyyards / awayWeeks, 2)
    pen_num_home = round(homeObject.numpenalties / homeWeeks, 2)
    pen_yards_home = round(homeObject.penaltyyards / homeWeeks, 2)
    fumbles_away = round(awayObject.fumbles / awayWeeks, 2)
    fumbles_away_recovered = round(awayObject.fumblesrecovered / awayWeeks, 2)
    fumbles_home = round(homeObject.fumbles / homeWeeks, 2)
    fumbles_home_recovered = round(homeObject.fumblesrecovered / homeWeeks, 2)
    interceptions_away = round(awayObject.interceptions / awayWeeks, 2)
    interceptions_away_received = round(awayObject.interceptionsrecovered / awayWeeks, 2)
    interceptions_home = round(homeObject.interceptions / homeWeeks, 2)
    interceptions_home_received = round(homeObject.interceptionsrecovered / homeWeeks, 2)
    possession_away = round(awayObject.timeofpossession / awayWeeks, 2)
    possession_home = round(homeObject.timeofpossession / homeWeeks, 2)
    datapoint = DataPoint(season, week, time_et, neutral, awayTeam, homeTeam, score_away, score_home, ppg_away, papg_away, ppg_home, papg_home, first_downs_away, first_downs_away_allowed, first_downs_home, first_downs_home_allowed, first_downs_from_passing_away, first_downs_from_passing_away_allowed, first_downs_from_passing_home, first_downs_from_passing_home_allowed, first_downs_from_rushing_away, first_downs_from_rushing_away_allowed, first_downs_from_rushing_home, first_downs_from_rushing_home_allowed, first_downs_from_penalty_away, first_downs_from_penalty_away_allowed, first_downs_from_penalty_home, first_downs_from_penalty_home_allowed, third_down_comp_away, third_down_comp_away_allowed, third_down_att_away, third_down_att_away_allowed, third_down_comp_home, third_down_comp_home_allowed, third_down_att_home, third_down_att_home_allowed, fourth_down_comp_away, fourth_down_comp_away_allowed, fourth_down_att_away, fourth_down_att_away_allowed, fourth_down_comp_home, fourth_down_comp_home_allowed, fourth_down_att_home, fourth_down_att_home_allowed, plays_away, plays_away_allowed, plays_home, plays_home_allowed, drives_away, drives_away_allowed, drives_home, drives_home_allowed, yards_away, yards_away_allowed, yards_home, yards_home_allowed, pass_comp_away, pass_comp_away_allowed, pass_att_away, pass_att_away_allowed, pass_yards_away, pass_yards_away_allowed, pass_comp_home, pass_comp_home_allowed, pass_att_home, pass_att_home_allowed, pass_yards_home, pass_yards_home_allowed, sacks_num_away, sacks_num_away_allowed, sacks_yards_away, sacks_yards_away_allowed, sacks_num_home, sacks_num_home_allowed, sacks_yards_home, sacks_yards_home_allowed, rush_att_away, rush_att_away_allowed, rush_yards_away, rush_yards_away_allowed, rush_att_home, rush_att_home_allowed, rush_yards_home, rush_yards_home_allowed, pen_num_away, pen_yards_away, pen_num_home, pen_yards_home, fumbles_away, fumbles_away_recovered, fumbles_home, fumbles_home_recovered, interceptions_away, interceptions_away_received, interceptions_home, interceptions_home_received, possession_away, possession_home)
    return datapoint
    
def unpackData(newdata):
    row = []
    for attr, value in newdata.__dict__.items():
        row.append(str(value))
    return row

def makeHeader():
    row = ["season", "week", "time_et", "neutral", "away", "home", "score_away", "score_home", "ppg_away", "papg_away", "ppg_home", "papg_home", "first_downs_away", "first_downs_away_allowed", "first_downs_home", "first_downs_home_allowed", "first_downs_from_passing_away", "first_downs_from_passing_away_allowed", "first_downs_from_passing_home", "first_downs_from_passing_home_allowed", "first_downs_from_rushing_away", "first_downs_from_rushing_away_allowed", "first_downs_from_rushing_home", "first_downs_from_rushing_home_allowed", "first_downs_from_penalty_away", "first_downs_from_penalty_away_allowed", "first_downs_from_penalty_home", "first_downs_from_penalty_home_allowed", "third_down_comp_away", "third_down_comp_away_allowed", "third_down_att_away", "third_down_att_away_allowed", "third_down_comp_home", "third_down_comp_home_allowed", "third_down_att_home", "third_down_att_home_allowed", "fourth_down_comp_away", "fourth_down_comp_away_allowed", "fourth_down_att_away", "fourth_down_att_away_allowed", "fourth_down_comp_home", "fourth_down_comp_home_allowed", "fourth_down_att_home", "fourth_down_att_home_allowed", "plays_away", "plays_away_allowed", "plays_home", "plays_home_allowed", "drives_away", "drives_away_allowed", "drives_home", "drives_home_allowed", "yards_away", "yards_away_allowed", "yards_home", "yards_home_allowed", "pass_comp_away", "pass_comp_away_allowed", "pass_att_away", "pass_att_away_allowed", "pass_yards_away", "pass_yards_away_allowed", "pass_comp_home", "pass_comp_home_allowed", "pass_att_home", "pass_att_home_allowed", "pass_yards_home", "pass_yards_home_allowed", "sacks_num_away", "sacks_num_away_allowed", "sacks_yards_away", "sacks_yards_away_allowed", "sacks_num_home", "sacks_num_home_allowed", "sacks_yards_home", "sacks_yards_home_allowed", "rush_att_away", "rush_att_away_allowed", "rush_yards_away", "rush_yards_away_allowed", "rush_att_home", "rush_att_home_allowed", "rush_yards_home", "rush_yards_home_allowed", "pen_num_away", "pen_yards_away", "pen_num_home", "pen_yards_home", "fumbles_away", "fumbles_away_recovered", "fumbles_home", "fumbles_home_recovered", "interceptions_away", "interceptions_away_received", "interceptions_home", "interceptions_home_received", "possession_away", "possession_home"]
    return row

# %%
class DataPoint:
    def __init__(self, season, week, time_et, neutral, away, home, score_away, score_home, ppg_away, papg_away, ppg_home, papg_home, first_downs_away, first_downs_away_allowed, first_downs_home, first_downs_home_allowed, first_downs_from_passing_away, first_downs_from_passing_away_allowed, first_downs_from_passing_home, first_downs_from_passing_home_allowed, first_downs_from_rushing_away, first_downs_from_rushing_away_allowed, first_downs_from_rushing_home, first_downs_from_rushing_home_allowed, first_downs_from_penalty_away, first_downs_from_penalty_away_allowed, first_downs_from_penalty_home, first_downs_from_penalty_home_allowed, third_down_comp_away, third_down_comp_away_allowed, third_down_att_away, third_down_att_away_allowed, third_down_comp_home, third_down_comp_home_allowed, third_down_att_home, third_down_att_home_allowed, fourth_down_comp_away, fourth_down_comp_away_allowed, fourth_down_att_away, fourth_down_att_away_allowed, fourth_down_comp_home, fourth_down_comp_home_allowed, fourth_down_att_home, fourth_down_att_home_allowed, plays_away, plays_away_allowed, plays_home, plays_home_allowed, drives_away, drives_away_allowed, drives_home, drives_home_allowed, yards_away, yards_away_allowed, yards_home, yards_home_allowed, pass_comp_away, pass_comp_away_allowed, pass_att_away, pass_att_away_allowed, pass_yards_away, pass_yards_away_allowed, pass_comp_home, pass_comp_home_allowed, pass_att_home, pass_att_home_allowed, pass_yards_home, pass_yards_home_allowed, sacks_num_away, sacks_num_away_allowed, sacks_yards_away, sacks_yards_away_allowed, sacks_num_home, sacks_num_home_allowed, sacks_yards_home, sacks_yards_home_allowed, rush_att_away, rush_att_away_allowed, rush_yards_away, rush_yards_away_allowed, rush_att_home, rush_att_home_allowed, rush_yards_home, rush_yards_home_allowed, pen_num_away, pen_yards_away, pen_num_home, pen_yards_home, fumbles_away, fumbles_away_recovered, fumbles_home, fumbles_home_recovered, interceptions_away, interceptions_away_received, interceptions_home, interceptions_home_received, possession_away, possession_home):
        self.season = season
        self.week = week
        self.time_et = time_et
        self.neutral = neutral
        self.away = away
        self.home = home
        self.score_away = score_away
        self.score_home = score_home
        self.ppg_away = ppg_away
        self.papg_away = papg_away
        self.ppg_home = ppg_home
        self.papg_home = papg_home
        self.first_downs_away = first_downs_away
        self.first_downs_away_allowed = first_downs_away_allowed
        self.first_downs_home = first_downs_home
        self.first_downs_home_allowed = first_downs_home_allowed
        self.first_downs_from_passing_away = first_downs_from_passing_away
        self.first_downs_from_passing_away_allowed = first_downs_from_passing_away_allowed
        self.first_downs_from_passing_home = first_downs_from_passing_home
        self.first_downs_from_passing_home_allowed = first_downs_from_passing_home_allowed
        self.first_downs_from_rushing_away = first_downs_from_rushing_away
        self.first_downs_from_rushing_away_allowed = first_downs_from_rushing_away_allowed
        self.first_downs_from_rushing_home = first_downs_from_rushing_home
        self.first_downs_from_rushing_home_allowed = first_downs_from_rushing_home_allowed
        self.first_downs_from_penalty_away = first_downs_from_penalty_away
        self.first_downs_from_penalty_away_allowed = first_downs_from_penalty_away_allowed
        self.first_downs_from_penalty_home = first_downs_from_penalty_home
        self.first_downs_from_penalty_home_allowed = first_downs_from_penalty_home_allowed
        self.third_down_comp_away = third_down_comp_away
        self.third_down_comp_away_allowed = third_down_comp_away_allowed
        self.third_down_att_away = third_down_att_away
        self.third_down_att_away_allowed = third_down_att_away_allowed
        self.third_down_comp_home = third_down_comp_home
        self.third_down_comp_home_allowed = third_down_comp_home_allowed
        self.third_down_att_home = third_down_att_home
        self.third_down_att_home_allowed = third_down_att_home_allowed
        self.fourth_down_comp_away = fourth_down_comp_away
        self.fourth_down_comp_away_allowed = fourth_down_comp_away_allowed
        self.fourth_down_att_away = fourth_down_att_away
        self.fourth_down_att_away_allowed = fourth_down_att_away_allowed
        self.fourth_down_comp_home = fourth_down_comp_home
        self.fourth_down_comp_home_allowed = fourth_down_comp_home_allowed
        self.fourth_down_att_home = fourth_down_att_home
        self.fourth_down_att_home_allowed = fourth_down_att_home_allowed
        self.plays_away = plays_away
        self.plays_away_allowed = plays_away_allowed
        self.plays_home = plays_home
        self.plays_home_allowed = plays_home_allowed
        self.drives_away = drives_away
        self.drives_away_allowed = drives_away_allowed
        self.drives_home = drives_home
        self.drives_home_allowed = drives_home_allowed
        self.yards_away = yards_away
        self.yards_away_allowed = yards_away_allowed
        self.yards_home = yards_home
        self.yards_home_allowed = yards_home_allowed
        self.pass_comp_away = pass_comp_away
        self.pass_comp_away_allowed = pass_comp_away_allowed
        self.pass_att_away = pass_att_away
        self.pass_att_away_allowed = pass_att_away_allowed
        self.pass_yards_away = pass_yards_away
        self.pass_yards_away_allowed = pass_yards_away_allowed
        self.pass_comp_home = pass_comp_home
        self.pass_comp_home_allowed = pass_comp_home_allowed
        self.pass_att_home = pass_att_home
        self.pass_att_home_allowed = pass_att_home_allowed
        self.pass_yards_home = pass_yards_home
        self.pass_yards_home_allowed = pass_yards_home_allowed
        self.sacks_num_away = sacks_num_away
        self.sacks_num_away_allowed = sacks_num_away_allowed
        self.sacks_yards_away = sacks_yards_away
        self.sacks_yards_away_allowed = sacks_yards_away_allowed
        self.sacks_num_home = sacks_num_home
        self.sacks_num_home_allowed = sacks_num_home_allowed
        self.sacks_yards_home = sacks_yards_home
        self.sacks_yards_home_allowed = sacks_yards_home_allowed
        self.rush_att_away = rush_att_away
        self.rush_att_away_allowed = rush_att_away_allowed
        self.rush_yards_away = rush_yards_away
        self.rush_yards_away_allowed = rush_yards_away_allowed
        self.rush_att_home = rush_att_home
        self.rush_att_home_allowed = rush_att_home_allowed
        self.rush_yards_home = rush_yards_home
        self.rush_yards_home_allowed = rush_yards_home_allowed
        self.pen_num_away = pen_num_away
        self.pen_yards_away = pen_yards_away
        self.pen_num_home = pen_num_home
        self.pen_yards_home = pen_yards_home
        self.fumbles_away = fumbles_away
        self.fumbles_away_recovered = fumbles_away_recovered
        self.fumbles_home = fumbles_home
        self.fumbles_home_recovered = fumbles_home_recovered
        self.interceptions_away = interceptions_away
        self.interceptions_away_received = interceptions_away_received
        self.interceptions_home = interceptions_home
        self.interceptions_home_received = interceptions_home_received
        self.possession_away = possession_away
        self.possession_home = possession_home
        
    def __str__(self):
        return f"{self.away} scored {self.score_away} points @ {self.home} who scored {self.score_home} points during a week {self.week} matchup. Leading up to the game, {self.away} averaged {self.ppg_away} points per game and allowed {self.papg_away} points per game. {self.home} averaged {self.ppg_home} points per game and allowed {self.papg_home} points per game."
        
class Team:
    def __init__(self, team):
        self.team = team
        self.numWeeks = 0
        self.points = 0
        self.pointsAllowed = 0
        self.firstdowns = 0
        self.firstdownsAllowed = 0
        self.firstdownspassing = 0
        self.firstdownspassingAllowed = 0
        self.firstdownsrushing = 0
        self.firstdownsrushingAllowed = 0
        self.firstdownspenalty = 0
        self.firstdownspenaltyAllowed = 0
        self.thirddowncompletions = 0
        self.thirddowncompletionsAllowed = 0
        self.thirddownattempts = 0
        self.thirddownattemptsAllowed = 0
        self.fourthdowncompletions = 0
        self.fourthdowncompletionsAllowed = 0
        self.fourthdownattempts = 0
        self.fourthdownattemptsAllowed = 0
        self.plays = 0
        self.playsAllowed = 0
        self.yards = 0
        self.yardsAllowed = 0
        self.drives = 0
        self.drivesAllowed = 0
        self.passcompletions = 0
        self.passattempts = 0
        self.passyards = 0
        self.passcompletionsAllowed = 0
        self.passattemptsAllowed = 0
        self.passyardsAllowed = 0
        self.numsacks = 0
        self.sackyards = 0
        self.numsacksAllowed = 0
        self.sackyardsAllowed = 0
        self.rushattempts = 0
        self.rushyards = 0
        self.rushattemptsAllowed = 0
        self.rushyardsAllowed  = 0
        self.numpenalties = 0
        self.penaltyyards = 0
        self.fumbles = 0
        self.fumblesrecovered = 0
        self.interceptions = 0
        self.interceptionsrecovered = 0
        self.timeofpossession = 0
    
    def __str__(self):
        return f"Through week {self.numWeeks}: {self.team} has scored {self.points} points, has let up {self.pointsAllowed} points on defense, and controlled the ball for {self.timeofpossession} seconds."

# %%
data = readFile(originalData)
headers = data[0]
teamDic = initTeams()
dataset = []
for num in range(1, len(data)):
    datapoint = data[num]
    if datapoint[0] == "2023":
        week = datapoint[1]
        if week == "1":
            updateStats(teamDic, datapoint)
        else:
            updatedData = createDatapoint(teamDic, datapoint)
            updateStats(teamDic, datapoint)
            if updatedData != None:
                row = unpackData(updatedData)
                dataset.append(row)
    else:
        continue
appendFile(changedData, dataset)
